# %% [markdown]
# <table>
#     <tr>
#     <th>
#         <table>
#             <tr>
#                  <th  style="font-size:150%;ftext-align:left;background-color:#053061;color:white;">Valeur</th>
#                  <th  style="font-size:150%;text-align:left;background-color:#053061;color:white;">Nom classe</th>
#              </tr>
#             <tr>
#                 <th  style="font-size:150%;text-align:left">0</th>
#                 <th  style="font-size:150%;text-align:left">eosinophil</th>
#             </tr>
#             <tr>
#                 <th  style="font-size:150%;text-align:left">1</th>
#                 <th  style="font-size:150%;text-align:left">lymphocyte</th>
#             </tr>
#             <tr>
#                 <th  style="font-size:150%;text-align:left">2</th>
#                 <th  style="font-size:150%;text-align:left">monocyte</th>
#             </tr>
#             <tr>
#                 <th  style="font-size:150%;text-align:left">3</th>
#                 <th  style="font-size:150%;text-align:left">neutrophil</th>
#             </tr>
#         </table>
#     </th>
#     <th>
#         <div style='padding:15px;color:#030aa7;font-size:240%;text-align: center;font-style: italic;font-weight: bold;font-family: Georgia, serif'>BloodMNIST<br> Standardized Biomedical Images</div>
#         <div style='text-align: center'>
#             <img src="https://raw.githubusercontent.com/rbizoi/DeepLearning/refs/heads/main/images/bood-4.png" width="512">
#         </div>
#     </th>
#     </tr>
# </table>
#
# <div style='padding:15px;color:#030aa7;font-size:100%;text-align: left;font-family: Georgia, serif'><a href="https://www.kaggle.com/datasets/kylewang1999/pbc-dataset">Veuillez vous référer à la page officielle pour plus de détails.</a></div>
#
# >> **site du projet** : https://data.mendeley.com/datasets/snkd93bnjr/1
#
# >> **article** : https://doi.org/10.1016/j.cmpb.2019.105020
#
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Initialisation du document</div></b>

# %%
import os
# import json
# @param ["tensorflow", "jax", "torch"]
# os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ['KERAS_BACKEND'] = 'tensorflow'  
os.environ['TF_XLA_FLAGS'] = '--tf_xla_enable_xla_devices'
os.environ['TF_CPP_MIN_LOG_LEVEL']='5'

import tensorflow as tf
import keras
tf.get_logger().setLevel('ERROR')

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Import libriries </div></b>

# %%
import numpy as np, pandas as pd, seaborn as sns, warnings, os, sys, time
from matplotlib import pyplot as plt

warnings.filterwarnings(action="ignore")

if int(str(sns.__version__).split('.')[1]) > 8 : 
    plt.style.use('seaborn-v0_8-darkgrid')
else:
    plt.style.use('seaborn-darkgrid')
    
sns.set(font_scale=2)

print(f"""La version des librairies utilisées :

Tensorflow : {tf.__version__}\tCUDA {tf.test.is_built_with_cuda()}\tGPU {tf.test.is_built_with_gpu_support()}\tXLA {tf.test.is_built_with_xla()}
Keras      : {keras.version()}
Pandas     : {pd.__version__}
NumPy      : {np.__version__}""")
# Out:
# La version des librairies utilisées :
#
# Tensorflow : 2.16.1	CUDA True	GPU True	XLA True
# Keras      : 3.1.1
# Pandas     : 2.2.1
# NumPy      : 1.26.4

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Outils du document</div></b>

# %%
sys.path.append(os.path.abspath('../outils/'))

# %%
if 'configProjet' in sys.modules.keys():  del(sys.modules['configProjet'])
if 'configModele' in sys.modules.keys():  del(sys.modules['configModele'])

# %%
from configProjet import palette, initParametresProjet 
from configProjet import afficheHistoriqueEntrainement, afficheProbabilites, afficheMatriceConfusion, afficheDataset, afficheDistributionsPipe

# %%
from configModele import modelDictionnaire, initParametresExecution, getPipelineDataset
from configModele import creationCompilationModele, creationRappelsExecution, entrainementModele
from configModele import sauvegarderModel, sauvegardeHistorique, executeApprentissageChoixClassifieurs
from configModele import modelCNNSimple, modelPersonalise, modelPersonaliseInception

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Paramétrés de l’exécution et les flux de lecture des fichiers TFRecors</div></b>

# %%
image_size,batch_size,epochs,dictLabels,nombreClasses,pipelineApprentissage,pipelineValidation = \
       initParametresExecution(image_size=(36, 36, 3),
                            batch_size = 32,
                            epochs=128,
                            repertoire='../donnees/BloodMNIST36x36-4',
                            cycle_length=None,
                            deterministic=None,
                            repetition=1,
                            bufferAleatoire=1024)

# %%
print(f"""
  image_size    = {image_size}
  batch_size    = {batch_size}
  epochs        = {epochs}
  nombreClasses = {nombreClasses}
  dictLabels    = {dictLabels}
       """)
# Out:
#   image_size    = (36, 36, 3)
#   batch_size    = 32
#   epochs        = 128
#   nombreClasses = 4
#   dictLabels    = {0: 'eosinophil', 1: 'lymphocyte', 2: 'monocyte', 3: 'neutrophil'}

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Affichage données</div></b>

# %%
images, labels = next(iter(pipelineApprentissage))
nombresImages = 8
afficheDataset(images, labels,nombresImages,6*nombresImages,dictLabels,cmap=None)

# %%
afficheDistributionsPipe(pipelineApprentissage, dictLabels, palette, repertoireEnregistrement=None)

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Choix du modèle</div></b>

# %%
nomModel = 'CNN-PersonaliseMNIST-36x36-4'

# %%
repertoireEnregistrement,repertoireSauvegardes,repertoireModelCKP,repertoireModelSauvegarde,repertoireModelLogs = \
            initParametresProjet(nomProjet=f"4.1-bloodMNIST-{nomModel}-bs{batch_size:02d}-epochs{epochs:03d}",repertoireProjet='../ResultatsExecutions')

# %%
repertoireModelSauvegarde
# Out:
# '../ResultatsExecutions/4.1-bloodMNIST-CNN-PersonaliseMNIST-36x36-4-bs32-epochs128/model.sauvegardes/sauvegarde'

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Création et compilation d'un modèle</div></b>

# %%
preprocessData = tf.keras.Sequential([
            keras.layers.Rescaling(1.0 / 255),
        ])

model = modelPersonaliseInception(image_size, 
                   nombreClasses, 
                   activation=keras.ops.gelu,
                   listeFiltres = [64,128,96,64],
                   preprocessData=preprocessData)

# %%
model.summary()
# Out:
# Model: "modelPersonaliseInception"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 36, 36, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ sequential          │ (None, 36, 36, 3) │          0 │ input_layer[0][0] │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 36, 36,    │      1,728 │ sequential[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 36, 36,    │        192 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 36, 36,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 36, 36,    │      8,192 │ activation[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 36, 36,    │        384 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 36, 36,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 36, 36,    │    147,456 │ activation_1[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 36, 36,    │    147,456 │ activation_1[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 36, 36,    │        384 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 36, 36,    │        384 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 36, 36,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 36, 36,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 36, 36,    │    147,456 │ activation_2[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d   │ (None, 36, 36,    │          0 │ activation[0][0]  │
# │ (AveragePooling2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 36, 36,    │     49,152 │ activation_5[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 36, 36,    │     49,152 │ activation_5[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 36, 36,    │     49,152 │ activation_1[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 36, 36,    │     49,152 │ activation_1[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 36, 36,    │        384 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 36, 36,    │      4,096 │ average_pooling2… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 36, 36,    │        384 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 36, 36,    │        384 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 36, 36,    │        384 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 36, 36,    │        384 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 36, 36,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 36, 36,    │        192 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 36, 36,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 36, 36,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 36, 36,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 36, 36,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 36, 36,    │          0 │ activation_2[0][… │
# │ (Concatenate)       │ 256)              │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 36, 36,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 36, 36,    │          0 │ activation_6[0][… │
# │ (Concatenate)       │ 256)              │            │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 36, 36,    │          0 │ activation_8[0][… │
# │ (Concatenate)       │ 256)              │            │ activation_9[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 36, 36,    │          0 │ concatenate[0][0… │
# │ (Concatenate)       │ 960)              │            │ activation_4[0][… │
# │                     │                   │            │ activation_1[0][… │
# │                     │                   │            │ concatenate_1[0]… │
# │                     │                   │            │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 18, 18,    │  1,105,920 │ concatenate_3[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 18, 18,    │      8,192 │ activation[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 18, 18,    │          0 │ conv2d_10[0][0],  │
# │                     │ 128)              │            │ conv2d_11[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 18, 18,    │     12,288 │ add[0][0]         │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 18, 18,    │        288 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 18, 18,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 18, 18,    │     82,944 │ activation_10[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 18, 18,    │     82,944 │ activation_10[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 18, 18,    │        288 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 18, 18,    │        288 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 18, 18,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 18, 18,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 18, 18,    │     82,944 │ activation_11[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_1 │ (None, 18, 18,    │          0 │ add[0][0]         │
# │ (AveragePooling2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 18, 18,    │     27,648 │ activation_14[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 18, 18,    │     27,648 │ activation_14[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 18, 18,    │     27,648 │ activation_10[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 18, 18,    │     27,648 │ activation_10[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 18, 18,    │        288 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 18, 18,    │      6,144 │ average_pooling2… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 18, 18,    │        288 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 18, 18,    │        288 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 18, 18,    │        288 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 18, 18,    │        288 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 18, 18,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 18, 18,    │        144 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 18, 18,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 18, 18,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 18, 18,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 18, 18,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 18, 18,    │          0 │ activation_11[0]… │
# │ (Concatenate)       │ 192)              │            │ activation_12[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 18, 18,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 18, 18,    │          0 │ activation_15[0]… │
# │ (Concatenate)       │ 192)              │            │ activation_16[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 18, 18,    │          0 │ activation_17[0]… │
# │ (Concatenate)       │ 192)              │            │ activation_18[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 18, 18,    │          0 │ concatenate_4[0]… │
# │ (Concatenate)       │ 720)              │            │ activation_13[0]… │
# │                     │                   │            │ activation_10[0]… │
# │                     │                   │            │ concatenate_5[0]… │
# │                     │                   │            │ concatenate_6[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 9, 9, 96)  │    622,080 │ concatenate_7[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 9, 9, 96)  │     12,288 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 9, 9, 96)  │          0 │ conv2d_21[0][0],  │
# │                     │                   │            │ conv2d_22[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 9, 9, 64)  │      6,144 │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 9, 9, 64)  │        192 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_19       │ (None, 9, 9, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 9, 9, 64)  │     36,864 │ activation_19[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_27 (Conv2D)  │ (None, 9, 9, 64)  │     36,864 │ activation_19[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 9, 9, 64)  │        192 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 9, 9, 64)  │        192 │ conv2d_27[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_20       │ (None, 9, 9, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_23       │ (None, 9, 9, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 9, 9, 64)  │     36,864 │ activation_20[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_2 │ (None, 9, 9, 96)  │          0 │ add_1[0][0]       │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_28 (Conv2D)  │ (None, 9, 9, 64)  │     12,288 │ activation_23[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_29 (Conv2D)  │ (None, 9, 9, 64)  │     12,288 │ activation_23[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_30 (Conv2D)  │ (None, 9, 9, 64)  │     12,288 │ activation_19[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_31 (Conv2D)  │ (None, 9, 9, 64)  │     12,288 │ activation_19[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 9, 9, 64)  │        192 │ conv2d_25[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_26 (Conv2D)  │ (None, 9, 9, 32)  │      3,072 │ average_pooling2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 9, 9, 64)  │        192 │ conv2d_28[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 9, 9, 64)  │        192 │ conv2d_29[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 9, 9, 64)  │        192 │ conv2d_30[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 9, 9, 64)  │        192 │ conv2d_31[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_21       │ (None, 9, 9, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 9, 9, 32)  │         96 │ conv2d_26[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_24       │ (None, 9, 9, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_25       │ (None, 9, 9, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_26       │ (None, 9, 9, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_27       │ (None, 9, 9, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (None, 9, 9, 128) │          0 │ activation_20[0]… │
# │ (Concatenate)       │                   │            │ activation_21[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_22       │ (None, 9, 9, 32)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_9       │ (None, 9, 9, 128) │          0 │ activation_24[0]… │
# │ (Concatenate)       │                   │            │ activation_25[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_10      │ (None, 9, 9, 128) │          0 │ activation_26[0]… │
# │ (Concatenate)       │                   │            │ activation_27[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_11      │ (None, 9, 9, 480) │          0 │ concatenate_8[0]… │
# │ (Concatenate)       │                   │            │ activation_22[0]… │
# │                     │                   │            │ activation_19[0]… │
# │                     │                   │            │ concatenate_9[0]… │
# │                     │                   │            │ concatenate_10[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_32 (Conv2D)  │ (None, 5, 5, 64)  │    276,480 │ concatenate_11[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_33 (Conv2D)  │ (None, 5, 5, 64)  │      6,144 │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 5, 5, 64)  │          0 │ conv2d_32[0][0],  │
# │                     │                   │            │ conv2d_33[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ add_2[0][0]       │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64)        │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 4)         │        260 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,238,708 (12.35 MB)
#  Trainable params: 3,233,684 (12.34 MB)
#  Non-trainable params: 5,024 (19.62 KB)

# %%
model.compile(
        optimizer=keras.optimizers.Adam(1e-03), 
        loss=keras.losses.SparseCategoricalCrossentropy(),
        metrics=[keras.metrics.SparseCategoricalAccuracy(name='accuracy')],
    )

# %% [markdown]
# # <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Rappels d’exécution (callbacks)</div></b>

# %%
callbacks = creationRappelsExecution(repertoireModelSauvegarde,
                                     repertoireModelCKP,
                                     repertoireModelLogs,
                                     patienceArretPrecoce=8,
                                     initial_lrate=1e-03,
                                     max_lrate=1e-03,
                                     min_lrate=1e-05,
                                     epochs_runup_lrate=0,
                                     epochs_sustain_lrate=0,
                                     drop_lrate=0.98)

# %% [markdown]
# # <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Evolution du taux d'apprentissage</div></b>

# %%
def evolutionTauxApprentissage(epoch,
                               initial_lrate=1e-03,
                               max_lrate=1e-03,
                               min_lrate=1e-05,
                               epochs_runup_lrate=0,
                               epochs_sustain_lrate=0,
                               drop_lrate=0.975):
    # epochs_drop = epochs * 0.1
    if epoch < epochs_runup_lrate:
        lrate = (max_lrate - initial_lrate) / epochs_runup_lrate * epoch + initial_lrate
    elif epoch < epochs_runup_lrate + epochs_sustain_lrate:
        lrate = max_lrate
    else:
        lrate = (max_lrate - min_lrate) * drop_lrate**(epoch - epochs_runup_lrate - epochs_sustain_lrate) + min_lrate
    return lrate

# %%
rng = [i for i in range(epochs)]
y = [evolutionTauxApprentissage(x) for x in rng]
plt.plot(rng, y)

print(f"L'évolution du taux d'apprentissage : du {y[0]:.3g} à {min(y):.3g}")
# Out:
# L'évolution du taux d'apprentissage : du 0.001 à 4.97e-05

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Entrainement du modèle</div></b>

# %%
historiqueApprentissage, model = entrainementModele( model, 
                                                     pipelineApprentissage,
                                                     pipelineValidation, 
                                                     epochs, 
                                                     batch_size,
                                                     callbacks,
                                                     2, #verbose=2, 
                                                     repertoireModelSauvegarde)
# Out:
# Epoch 1/128
# I0000 00:00:1757243494.786490   59602 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1757243522.389903   59605 asm_compiler.cc:369] ptxas warning : Registers are spilled to local memory in function 'input_reduce_fusion_101', 4 bytes spill stores, 4 bytes spill loads
# Epoch 1: val_loss improved from inf to 3.14235, saving model to ../ResultatsExecutions/4.1-bloodMNIST-CNN-PersonaliseMNIST-36x36-4-bs32-epochs128/model.sauvegardes/sauvegarde/modelVLoss.keras
# 1277/1277 - 55s - 43ms/step - accuracy: 0.9268 - loss: 0.3864 - val_accuracy: 0.7093 - val_loss: 3.1423 - learning_rate: 0.0010
# Epoch 2/128
#
# Epoch 2: val_loss improved from 3.14235 to 0.40211, saving model to ../ResultatsExecutions/4.1-bloodMNIST-CNN-PersonaliseMNIST-36x36-4-bs32-epochs128/model.sauvegardes/sauvegarde/modelVLoss.keras
# 1277/1277 - 18s - 14ms/step - accuracy: 0.9697 - loss: 0.1191 - val_accuracy: 0.9262 - val_loss: 0.4021 - learning_rate: 9.8020e-04
# Epoch 3/128
#
# Epoch 3: val_loss improved from 0.40211 to 0.17579, saving model to ../ResultatsExecutions/4.1-bloodMNIST-CNN-PersonaliseMNIST-36x36-4-bs32-epochs128/model.sauvegardes/sauvegarde/modelVLoss.keras
# 1277/1277 - 18s - 14ms/step - accuracy: 0.9802 - loss: 0.0694 - val_accuracy: 0.9515 - val_loss: 0.1758 - learning_rate: 9.6080e-04
# Epoch 4/128
#
# Epoch 4: val_loss did not improve from 0.17579
# 1277/1277 - 18s - 14ms/step - accuracy: 0.9817 - loss: 0.0626 - val_accuracy: 0.8524 - val_loss: 0.5265 - learning_rate: 9.4178e-04
# Epoch 5/128
#
# Epoch 5: val_loss did not improve from 0.17579
# 1277/1277 - 18s - 14ms/step - accuracy: 0.9851 - loss: 0.0503 - val_accuracy: 0.4747 - val_loss: 8.1830 - learning_rate: 9.2314e-04
# Epoch 6/128
#
# Epoch 6: val_loss improved from 0.17579 to 0.08107, saving model to ../ResultatsExecutions/4.1-bloodMNIST-CNN-PersonaliseMNIST-36x36-4-bs32-epochs128/model.sauvegardes/sauvegarde/modelVLoss.keras
# 1277/1277 - 18s - 14ms/step - accuracy: 0.9864 - loss: 0.0447 - val_accuracy: 0.9802 - val_loss: 0.0811 - learning_rate: 9.0488e-04
# Epoch 7/128
#
# Epoch 7: val_loss improved from 0.08107 to 0.04332, saving model to ../ResultatsExecutions/4.1-bloodMNIST-CNN-PersonaliseMNIST-36x36-4-bs32-epochs128/model.sauvegardes/sauvegarde/modelVLoss.keras
# 1277/1277 - 18s - 14ms/step - accuracy: 0.9876 - loss: 0.0415 - val_accuracy: 0.9879 - val_loss: 0.0433 - learning_rate: 8.8698e-04
# Epoch 8/128
#
# Epoch 8: val_loss did not improve from 0.04332
# 1277/1277 - 18s - 14ms/step - accuracy: 0.9889 - loss: 0.0373 - val_accuracy: 0.9813 - val_loss: 0.0615 - learning_rate: 8.6944e-04
# Epoch 9/128
#
# Epoch 9: val_loss did not improve from 0.04332
# 1277/1277 - 18s - 14ms/step - accuracy: 0.9903 - loss: 0.0322 - val_accuracy: 0.9317 - val_loss: 0.2238 - learning_rate: 8.5226e-04
# Epoch 10/128
#
# Epoch 10: val_loss improved from 0.04332 to 0.03695, saving model to ../ResultatsExecutions/4.1-bloodMNIST-CNN-PersonaliseMNIST-36x36-4-bs32-epochs128/model.sauvegardes/sauvegarde/modelVLoss.keras
# 1277/1277 - 18s - 14ms/step - accuracy: 0.9902 - loss: 0.0326 - val_accuracy: 0.9901 - val_loss: 0.0369 - learning_rate: 8.3541e-04
# Epoch 11/128
#
# Epoch 11: val_loss did not improve from 0.03695
# 1277/1277 - 18s - 14ms/step - accuracy: 0.9918 - loss: 0.0274 - val_accuracy: 0.9780 - val_loss: 0.0822 - learning_rate: 8.1890e-04
# Epoch 12/128
#
# Epoch 12: val_loss did not improve from 0.03695
# 1277/1277 - 18s - 14ms/step - accuracy: 0.9929 - loss: 0.0232 - val_accuracy: 0.9802 - val_loss: 0.0663 - learning_rate: 8.0272e-04
# Epoch 13/128
#
# Epoch 13: val_loss improved from 0.03695 to 0.03024, saving model to ../ResultatsExecutions/4.1-bloodMNIST-CNN-PersonaliseMNIST-36x36-4-bs32-epochs128/model.sauvegardes/sauvegarde/modelVLoss.keras
# 1277/1277 - 18s - 14ms/step - accuracy: 0.9938 - loss: 0.0204 - val_accuracy: 0.9956 - val_loss: 0.0302 - learning_rate: 7.8687e-04
# Epoch 14/128
#
# Epoch 14: val_loss did not improve from 0.03024
# 1277/1277 - 18s - 14ms/step - accuracy: 0.9932 - loss: 0.0228 - val_accuracy: 0.9912 - val_loss: 0.0422 - learning_rate: 7.7133e-04
# Epoch 15/128
#
# Epoch 15: val_loss did not improve from 0.03024
# 1277/1277 - 18s - 14ms/step - accuracy: 0.9945 - loss: 0.0181 - val_accuracy: 0.9747 - val_loss: 0.1036 - learning_rate: 7.5611e-04
# Epoch 16/128
#
# Epoch 16: val_loss did not improve from 0.03024
# 1277/1277 - 18s - 14ms/step - accuracy: 0.9944 - loss: 0.0197 - val_accuracy: 0.9890 - val_loss: 0.0409 - learning_rate: 7.4118e-04
# Epoch 17/128
#
# Epoch 17: val_loss improved from 0.03024 to 0.02230, saving model to ../ResultatsExecutions/4.1-bloodMNIST-CNN-PersonaliseMNIST-36x36-4-bs32-epochs128/model.sauvegardes/sauvegarde/modelVLoss.keras
# 1277/1277 - 18s - 14ms/step - accuracy: 0.9952 - loss: 0.0161 - val_accuracy: 0.9923 - val_loss: 0.0223 - learning_rate: 7.2656e-04
# Epoch 18/128
#
# Epoch 18: val_loss did not improve from 0.02230
# 1277/1277 - 18s - 14ms/step - accuracy: 0.9956 - loss: 0.0145 - val_accuracy: 0.8899 - val_loss: 1.0745 - learning_rate: 7.1223e-04
# Epoch 19/128
#
# Epoch 19: val_loss did not improve from 0.02230
# 1277/1277 - 18s - 14ms/step - accuracy: 0.9959 - loss: 0.0150 - val_accuracy: 0.9901 - val_loss: 0.0359 - learning_rate: 6.9818e-04
# Epoch 20/128
#
# Epoch 20: val_loss did not improve from 0.02230
# 1277/1277 - 18s - 14ms/step - accuracy: 0.9962 - loss: 0.0126 - val_accuracy: 0.9526 - val_loss: 0.1880 - learning_rate: 6.8442e-04
# Epoch 21/128
#
# Epoch 21: val_loss did not improve from 0.02230
# 1277/1277 - 18s - 14ms/step - accuracy: 0.9974 - loss: 0.0105 - val_accuracy: 0.9879 - val_loss: 0.0722 - learning_rate: 6.7093e-04
# Epoch 22/128
#
# Epoch 22: val_loss did not improve from 0.02230
# 1277/1277 - 18s - 14ms/step - accuracy: 0.9967 - loss: 0.0119 - val_accuracy: 0.9780 - val_loss: 0.1207 - learning_rate: 6.5771e-04
# Epoch 23/128
#
# Epoch 23: val_loss did not improve from 0.02230
# 1277/1277 - 18s - 14ms/step - accuracy: 0.9974 - loss: 0.0087 - val_accuracy: 0.9813 - val_loss: 0.1324 - learning_rate: 6.4476e-04
# Epoch 24/128
#
# Epoch 24: val_loss did not improve from 0.02230
# 1277/1277 - 18s - 14ms/step - accuracy: 0.9969 - loss: 0.0092 - val_accuracy: 0.9890 - val_loss: 0.0485 - learning_rate: 6.3206e-04
# Epoch 25/128
#
# Epoch 25: val_loss did not improve from 0.02230
# 1277/1277 - 18s - 14ms/step - accuracy: 0.9972 - loss: 0.0099 - val_accuracy: 0.9901 - val_loss: 0.0761 - learning_rate: 6.1962e-04
# Epoch 25: early stopping
# Exécution  : 8.16 m

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Affichage historique de l'apprentissage </div></b>

# %%
historique = sauvegardeHistorique(historiqueApprentissage,
                                  repertoireSauvegardes,
                                  nomSauvegarde=f'historique-{nomModel}-bs{batch_size:02d}-epochs{epochs:03d}')

# %%
afficheHistoriqueEntrainement(historique, palette, f'{nomModel}-bs{batch_size:02d}-epochs{epochs:03d}', repertoireEnregistrement)

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Sauvegarde du modèle </div></b>

# %%
model.save(os.path.join(repertoireModelSauvegarde,f'{nomModel}-bs{batch_size:02d}-epochs{epochs:03d}.keras'))

# %% [markdown]
# # <b><div style='padding:18px;background-color:#d8dcd6;color:#030aa7;font-size:130%; border-radius:12px 12px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Inférence</div></b>

# %%
for i, (img,lab) in enumerate(pipelineValidation): 
    images, labels = img if i==0 else tf.concat([images,img], 0), lab if i==0 else tf.concat([labels,lab], 0)

# %%
probabilities = model.predict(images, verbose=0)
predictions = np.argmax(probabilities, axis=-1)

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Probabilités pour les 8 premiers prédictions </div></b>

# %%
nombresImages = 8
afficheDataset(images, labels,nombresImages,6*nombresImages,dictLabels,cmap=None)
fig, ax = plt.subplots(nrows=1, ncols=nombresImages,figsize=(6*nombresImages,6));
for i in range(nombresImages):
    afficheProbabilites(probabilities,ind=i,ax=ax[i], dictLabels=dictLabels)

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Matrice de Confusion </div></b>

# %%
afficheDistributionsPipe(pipelineValidation, dictLabels, palette, repertoireEnregistrement=None)

# %%
afficheMatriceConfusion(observations=labels,predictions=predictions,dictLabels=dictLabels, repertoireEnregistrement=repertoireEnregistrement,
                        nom_essai = f'{nomModel}-bs{batch_size:02d}-epochs{epochs:03d}')

# %% [markdown]
# ## <b><div style='padding:15px;background-color:#d8dcd6;color:#030aa7;font-size:100%; border-radius:10px 10px; box-shadow: 8px 8px 8px #042b4c;text-align: left'>Résultats de l’apprentissage</div></b>

# %%
resultats = executeApprentissageChoixClassifieurs(
                                                  model,
                                                  X_test=images,
                                                  y_test=labels,
                                                  label_dict=dictLabels,
                                                  palette=palette, 
                                                  repertoireEnregistrement=repertoireEnregistrement,    
                                                  nom_essai = f'{nomModel}-bs{batch_size:02d}-epochs{epochs:03d}',
                                                 );

resultats.to_parquet(os.path.join(repertoireSauvegardes,f'resultats-{nomModel}-bs{batch_size:02d}-epochs{epochs:03d}.gzip'),compression='gzip', engine='pyarrow')

resultats
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Area under the ROC curve : 0.9999	--	Exécution  :4.82s
#        Classe    aucROC  avgPrecRec        f1        f2       f05  accuracy  \
# 0      global  0.999867    0.999794  0.992290  0.992289  0.992295  0.992291
# 1  eosinophil  0.999978    0.999959  0.998390  0.997426  0.999355  0.998899
# 2  lymphocyte  0.999859    0.998992  0.976526  0.979284  0.973783  0.994493
# 3    monocyte  0.999634    0.997969  0.975439  0.973389  0.977496  0.992291
# 4  neutrophil  0.999995    0.999992  0.998565  0.999426  0.997706  0.998899
#
#    precision  sensibilite  vrais_positifs  vrais_negatifs  faux_positifs  \
# 0   0.992302     0.992291             901            2717              7
# 1   1.000000     0.996785             310             597              0
# 2   0.971963     0.981132             104             799              3
# 3   0.978873     0.972028             139             762              3
# 4   0.997135     1.000000             348             559              1
#
#    faux_negatifs  total_positifs                                        essai
# 0              7             908  CNN-PersonaliseMNIST-36x36-4-bs32-epochs128
# 1              1             311  CNN-PersonaliseMNIST-36x36-4-bs32-epochs128
# 2              2             106  CNN-PersonaliseMNIST-36x36-4-bs32-epochs128
# 3              4             143  CNN-PersonaliseMNIST-36x36-4-bs32-epochs128
# 4              0             348  CNN-PersonaliseMNIST-36x36-4-bs32-epochs128
